# %%
import os
import numpy as np
import pandas as pd
import cv2
from glob import glob
from skimage import measure, morphology
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from scipy.spatial import ConvexHull
import pandas as pd

# %%
# Paths
image_dir = "images_and_labels/"
label_dir = "images_and_labels/"

image_files = sorted(glob(os.path.join(image_dir, "*.tiff")))
label_files = sorted(glob(os.path.join(label_dir, "*.txt")))

def load_labels(txt_file):
    df = pd.read_csv(txt_file)
    # Assuming columns: x, y, label
    return df

# %%
os.getcwd()
# Out:
# 'C:\\Users\\indhi\\ML_Corneal_Endothellium_Imaging'

# %%
print(image_dir)
# Out:
# images_and_labels/

# %%
len(image_files)
# Out:
# 385

# %%
def preprocess_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.equalizeHist(img)   # histogram equalization
    img = img / 255.0             # normalize
    return img

# %%
import matplotlib.pyplot as plt
import cv2

# Preprocess the image
img_path = "images_and_labels/71866.tiff"  # replace with your image path
img_processed = preprocess_image(img_path)

# Display the image
plt.imshow(img_processed, cmap='gray')
plt.title("Processed Image")
plt.axis('off')
plt.show()

# %%
import os
print(os.path.exists("images/71866.tiff"))
# Out:
# False

# %%
# ---------------- PARAMETERS ----------------
IMG_SIZE = 256 # resizing for unet
PIXEL_TO_MM2 = 0.0001  # adjust for your image calibration
CELL_MIN_SIZE = 50     # min pixels to count as a cell

# %%
# ---------------- FUNCTIONS ----------------

# Preprocessing
def preprocess_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise FileNotFoundError(f"Cannot read image: {img_path}")
    img = cv2.equalizeHist(img)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img = img / 255.0
    return img[..., np.newaxis]  # add channel for U-Net

# %%
### Visualzing the preprocessing and resizing


import matplotlib.pyplot as plt
import cv2

# Preprocess the image
img_path = "images_and_labels/71866.tiff"  # replace with your image path
img_processed = preprocess_image(img_path)

orig_img = cv2.imread(img_path)
height, width = orig_img.shape[:2]  # shape = (height, width, channels)
print(f"Original size: {width} x {height} pixels")

height, width = img_processed.shape[:2]  # shape = (height, width, channels)
print(f"Processed size: {width} x {height} pixels")

# Display the image
plt.imshow(orig_img, cmap='gray')
plt.title("Original Image")
plt.axis('off')
plt.show()

plt.imshow(img_processed, cmap='gray')
plt.title("Processed Image")
plt.axis('off')
plt.show()
# Out:
# Original size: 260 x 477 pixels
# Processed size: 256 x 256 pixels

# %%
# mask creation function from coordinates:



IMG_SIZE = 256
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import pandas as pd

# --- Include the fixed create_mask_from_txt function ---
def create_mask_from_txt(txt_file, target_size, original_size):
    orig_h, orig_w = original_size
    new_h, new_w = target_size

    scale_x = new_w / orig_w
    scale_y = new_h / orig_h

    mask = np.zeros((new_h, new_w), dtype=np.uint8)
    df = pd.read_csv(txt_file, sep="\t")

    for _, row in df.iterrows():
        x = int(row["x"] * scale_x)
        y = int(row["y"] * scale_y)
        x = np.clip(x, 0, new_w - 1)
        y = np.clip(y, 0, new_h - 1)
        mask[y, x] = 1
        cv2.circle(mask, (x, y), radius=3, color=1, thickness=-1)

    return mask

# -------------------

# %%
# --- Check size and values ---

#Example
img_path = "images_and_labels/71866.tiff"
txt_file = "images_and_labels/71866.txt"

# Load original image to get shape
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# Set target size
target_size = (256, 256)  # example

# Create mask directly at target size
mask_resized = create_mask_from_txt(txt_file, target_size, img.shape)

print("Resized mask shape:", mask_resized.shape)
print("Unique values in resized mask:", np.unique(mask_resized))
print("Mask shape:", mask_img.shape)
# Out:
# Resized mask shape: (256, 256)
# Unique values in resized mask: [0 1]
# Mask shape: (477, 260)

# %%
# Visulaizaing the created mask



img_path = "images_and_labels/71866.tiff"
txt_file = "images_and_labels/71866.txt"

# Load original image
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
if img is None:
    raise FileNotFoundError("Image not found!")

# Set target size
target_size = (256, 256)

# Create mask directly at target size
mask_resized = create_mask_from_txt(txt_file, target_size, img.shape)

print("Resized mask shape:", mask_resized.shape)
print("Unique values in resized mask:", np.unique(mask_resized))

# Optional: resize image for visualization to match mask
img_resized = cv2.resize(img, (target_size[1], target_size[0]), interpolation=cv2.INTER_LINEAR)

# -------------------
plt.figure(figsize=(15,4))

plt.subplot(1,4,1)
plt.imshow(img, cmap="gray")
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(img_resized, cmap="gray")
plt.title("Resized Image")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(mask_resized, cmap="gray")
plt.title("Resized Mask")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(img_resized, cmap="gray")
plt.imshow(mask_resized, cmap="jet", alpha=0.5)
plt.title("Overlay")
plt.axis("off")

plt.show()
# Out:
# Resized mask shape: (256, 256)
# Unique values in resized mask: [0 1]

# %%
### visualizing the created mask

import matplotlib.pyplot as plt
import cv2
import os

# Example paths
img_path_new = "images_and_labels/71866.tiff"
txt_path = "images_and_labels/71866.txt"

# Load original image
img_new = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

plt.subplot(1,1,1)
plt.imshow(img_new, cmap="gray")
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(259.5), np.float64(476.5), np.float64(-0.5))

# %%
# Build a simple U-Net model
def build_unet(input_shape=(IMG_SIZE, IMG_SIZE, 1)):
    inputs = layers.Input(input_shape)
    
    # Encoder
    c1 = layers.Conv2D(16, (3,3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, (3,3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)
    
    c2 = layers.Conv2D(32, (3,3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, (3,3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)
    
    # Bottleneck
    c3 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c3)
    
    # Decoder
    u1 = layers.UpSampling2D((2,2))(c3)
    concat1 = layers.concatenate([u1, c2])
    c4 = layers.Conv2D(32, (3,3), activation='relu', padding='same')(concat1)
    c4 = layers.Conv2D(32, (3,3), activation='relu', padding='same')(c4)
    
    u2 = layers.UpSampling2D((2,2))(c4)
    concat2 = layers.concatenate([u2, c1])
    c5 = layers.Conv2D(16, (3,3), activation='relu', padding='same')(concat2)
    c5 = layers.Conv2D(16, (3,3), activation='relu', padding='same')(c5)
    
    outputs = layers.Conv2D(1, (1,1), activation='sigmoid')(c5)
    
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
### Loading img and mask for u-net training


def load_dataset(image_dir, txt_dir):
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith(".tiff")])
    txt_files   = sorted([f for f in os.listdir(txt_dir) if f.endswith(".txt")])
    
    X = []
    Y = []
    
    for img_file, txt_file in zip(image_files, txt_files):
        img_path = os.path.join(image_dir, img_file)
        txt_path = os.path.join(txt_dir, txt_file)
        
        # Load image
        img = preprocess_image(img_path)
        
        # Load mask
        orig_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        mask_resized = create_mask_from_txt(txt_path, orig_img.shape)
        
        
        X.append(img)
        Y.append(mask_resized)
    
    return np.array(X, dtype=np.float32), np.array(Y, dtype=np.float32)

# %%
IMG_SIZE = 256

def load_dataset(image_dir, txt_dir):
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith(".tiff")])
    
    X = []
    Y = []
    
    for img_file in image_files:
        base_name = os.path.splitext(img_file)[0]
        txt_file = base_name + ".txt"
        
        img_path = os.path.join(image_dir, img_file)
        txt_path = os.path.join(txt_dir, txt_file)
        
        # Skip if mask file does not exist
        if not os.path.exists(txt_path):
            continue
        
        # --- Load original image (for scaling mask coordinates) ---
        orig_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if orig_img is None:
            continue
        
        orig_h, orig_w = orig_img.shape
        
        # --- Resize image for U-Net ---
        img_resized = cv2.resize(orig_img, (IMG_SIZE, IMG_SIZE))
        img_resized = img_resized / 255.0
        img_resized = np.expand_dims(img_resized, axis=-1)  # (256,256,1)
        
        # --- Create mask directly at target size ---
        mask_resized = create_mask_from_txt(
            txt_file=txt_path,
            target_size=(IMG_SIZE, IMG_SIZE),
            original_size=(orig_h, orig_w)
        )
        
        mask_resized = np.expand_dims(mask_resized, axis=-1)  # (256,256,1)
        
        X.append(img_resized)
        Y.append(mask_resized)
    
    return np.array(X, dtype=np.float32), np.array(Y, dtype=np.float32)

# %%
# Example

image_dir = "images_and_labels/"
txt_dir   = "images_and_labels/"

X, Y = load_dataset(image_dir, txt_dir)

print("X shape:", X.shape)  # e.g., (num_images, 256, 256, 1)
print("Y shape:", Y.shape)  # e.g., (num_images, 256, 256, 1)
print("Unique values in mask:", np.unique(Y))
# Out:
# X shape: (385, 256, 256, 1)
# Y shape: (385, 256, 256, 1)
# Unique values in mask: [0. 1.]

# %%
## Unet training
## step1: splitting the data

from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

print(X_train.shape, X_val.shape)
print(Y_train.shape, Y_val.shape)
# Out:
# (308, 256, 256, 1) (77, 256, 256, 1)
# (308, 256, 256, 1) (77, 256, 256, 1)

# %%
## step 2: Building the u-net model
from tensorflow.keras import layers, models

model = build_unet(input_shape=(IMG_SIZE, IMG_SIZE, 1))
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 256, 256, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_22 (Conv2D)            │ (None, 256, 256, 16)      │             160 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_23 (Conv2D)            │ (None, 256, 256, 16)      │           2,320 │ conv2d_22[0][0]            │
# ...

# %%
## train the model

history = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    batch_size=8,
    epochs=20
)
# Out:
# Epoch 1/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 30s 624ms/step - accuracy: 0.9424 - loss: 0.2560 - val_accuracy: 0.9913 - val_loss: 0.0545
# Epoch 2/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 40s 606ms/step - accuracy: 0.9917 - loss: 0.0492 - val_accuracy: 0.9913 - val_loss: 0.0488
# Epoch 3/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 24s 603ms/step - accuracy: 0.9917 - loss: 0.0469 - val_accuracy: 0.9913 - val_loss: 0.0482
# Epoch 4/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 24s 617ms/step - accuracy: 0.9917 - loss: 0.0462 - val_accuracy: 0.9913 - val_loss: 0.0494
# Epoch 5/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 24s 608ms/step - accuracy: 0.9917 - loss: 0.0467 - val_accuracy: 0.9913 - val_loss: 0.0492
# Epoch 6/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 24s 600ms/step - accuracy: 0.9917 - loss: 0.0462 - val_accuracy: 0.9913 - val_loss: 0.0478
# Epoch 7/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 24s 606ms/step - accuracy: 0.9917 - loss: 0.0466 - val_accuracy: 0.9913 - val_loss: 0.0489
# Epoch 8/20
# ...

# %%
## Visualize the predictions

image_files = sorted([f for f in os.listdir(image_dir) if f.endswith(".tiff")])

print(image_files[0])


import matplotlib.pyplot as plt

idx = 31 # example image
pred_mask = model.predict(X_val[idx:idx+1])[0,...,0]

print(pred_mask)


plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.imshow(X_val[idx,...,0], cmap='gray')
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(Y_val[idx,...,0], cmap='gray')
plt.title("Ground Truth Mask")
plt.axis("off")



plt.subplot(1,3,3)
plt.imshow(X_val[idx,...,0], cmap='gray') # original image
plt.imshow(pred_mask, cmap='jet', alpha=0.4)# predicted mask overlay
plt.title("Predicted Mask Overlay")
plt.axis("off")
plt.show()

print("Min:", pred_mask.min())
print("Max:", pred_mask.max())
print("Mean:", pred_mask.mean())

print("Positive pixels:", np.sum(Y_val[idx]))
print("Ratio:", np.sum(Y_val[idx]) / (256*256))
# Out:
# 71866.tiff
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# [[0.50007266 0.5000968  0.5001049  ... 0.5001534  0.50013304 0.500129  ]
#  [0.500106   0.5001385  0.50009865 ... 0.5002341  0.5002053  0.50022054]
#  [0.50007766 0.50008917 0.50008    ... 0.50036085 0.5003109  0.50016284]
#  ...
#  [0.5002203  0.50021225 0.50027823 ... 0.50029945 0.5002506  0.5001528 ]
#  [0.5001189  0.5001464  0.50023663 ... 0.50022656 0.50026244 0.5001139 ]
#  [0.49998924 0.50010043 0.5000531  ... 0.50006914 0.5000892  0.49998558]]
# Min: 0.49998558
# Max: 0.51371187
# Mean: 0.5063337
# Positive pixels: 340.0
# Ratio: 0.0051879883

# %%
pred_mask_raw = model.predict(X_val[idx:idx+1])[0, :, :, 0]  # values between 0 and 1

plt.imshow(pred_mask_raw, cmap='gray')
plt.colorbar()
plt.title("Predicted Mask (Confidence)")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step

# %%
# Assuming pred_mask_raw has shape (256, 256)
plt.imshow(X_val[idx, :, :, 0], cmap='gray')       # original image
plt.imshow(pred_mask_raw, cmap='jet', alpha=0.4)   # overlay predicted mask confidence
plt.title("Overlay Confidence")
plt.axis('off')
plt.show()

# %%
# Segment cells using U-Net
def segment_with_unet(model, img):
    pred_mask = model.predict(np.expand_dims(img, axis=0))[0, ..., 0]
    # Convert probability map to binary mask
    mask = (pred_mask > 0.2).astype(np.uint8)
    
    # Morphological cleaning
    #mask = morphology.remove_small_objects(mask.astype(bool), min_size=2)
    #mask = morphology.remove_small_holes(mask, area_threshold=2)
    
    # Label cells
    labeled_mask = measure.label(mask)
    return labeled_mask

# %%
idx = 31   # choose any index

img_example = X_val[idx]     # shape (256,256,1)
labeled_mask = segment_with_unet(model, img_example)

print("Labeled mask shape:", labeled_mask.shape)
print("Number of detected cells:", len(np.unique(labeled_mask)) - 1)

# Visualize
plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
plt.imshow(img_example[...,0], cmap="gray")
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(labeled_mask > 0, cmap="gray")
plt.title("Labeled Cells")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(img_example[...,0], cmap="gray")
plt.imshow(labeled_mask > 0, cmap="jet", alpha=0.4)
plt.title("Overlay")
plt.axis("off")

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Labeled mask shape: (256, 256)
# Number of detected cells: 0

# %%
txt_path = "images_and_labels/71897.txt"

df = pd.read_csv(txt_path, sep="\t")

num_annotations = len(df)

print("Number of annotated cells:", num_annotations)
# Out:
# Number of annotated cells: 97

# %%
# Feature extraction
def extract_features(labeled_mask):
    props = measure.regionprops(labeled_mask)
    areas = [p.area for p in props if p.area > 0]
    
    # Density
    density = len(areas) / PIXEL_TO_MM2
    
    # Coefficient of Variation
    cv = np.std(areas)/np.mean(areas) if len(areas) > 0 else 0
    
    # Hexagonality
    hex_count = 0
    for p in props:
        coords = p.coords
        if len(coords) < 3:
            continue
        try:
            hull = ConvexHull(coords)
            sides = len(hull.simplices)
            if sides == 6:
                hex_count += 1
        except:
            continue
    hexagonality = 100 * hex_count / len(areas) if len(areas) > 0 else 0
    
    return {"density": density, "cv": cv, "hexagonality": hexagonality}

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tifffile import imread
from scipy.spatial import Voronoi

def preprocess_pipeline(image_dir, text_dir, output_dir, img_size=(256, 256)):
    """
    Step 1: Preprocessing TIFFs and Text Files into U-Net ready Masks.
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # Paths for images and masks
    images_save_path = os.path.join(output_dir, "images")
    masks_save_path = os.path.join(output_dir, "masks")
    os.makedirs(images_save_path, exist_ok=True)
    os.makedirs(masks_save_path, exist_ok=True)

    for file_name in os.listdir(image_dir):
        if file_name.endswith('.tiff'):
            # 1. Load TIFF Image
            img_path = os.path.join(image_dir, file_name)
            image = imread(img_path)
            
            # Normalize image to 0-255 range and convert to uint8
            image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            h, w = image.shape[:2]

            # 2. Load Coordinates (Handling the 'id x y tag' format)
            txt_name = file_name.replace('.tiff', '.txt')
            txt_path = os.path.join(text_dir, txt_name)
            
            if not os.path.exists(txt_path):
                print(f"Skipping {file_name}: Text file not found.")
                continue

            # Read CSV with tab or space delimiter, skipping the header
            try:
                df = pd.read_csv(txt_path, sep='\s+', engine='python')
                points = df[['x', 'y']].values
            except Exception as e:
                print(f"Error reading {txt_path}: {e}")
                continue

            # 3. Create Multi-Class Mask
            # Class 0: Background, Class 1: Interior, Class 2: Boundary
            mask = np.zeros((h, w), dtype=np.uint8)

            # Generate Boundaries using Voronoi Tesselation
            if len(points) >= 4:
                vor = Voronoi(points)
                for ridge in vor.ridge_vertices:
                    if -1 not in ridge:
                        # Get vertex coordinates
                        v1 = vor.vertices[ridge[0]].astype(int)
                        v2 = vor.vertices[ridge[1]].astype(int)
                        # Draw boundaries as Class 2
                        cv2.line(mask, tuple(v1), tuple(v2), 2, thickness=2)

            # Draw Cell Centers as Class 1
            for pt in points:
                cv2.circle(mask, (int(pt[0]), int(pt[1])), 3, 1, -1)

            # 4. Resize and Save
            # We resize to a power of 2 (e.g., 512x512) for U-Net compatibility
            final_img = cv2.resize(image, img_size)
            final_mask = cv2.resize(mask, img_size, interpolation=cv2.INTER_NEAREST)

            base_name = os.path.splitext(file_name)[0]
            cv2.imwrite(os.path.join(images_save_path, f"{base_name}.png"), final_img)
            cv2.imwrite(os.path.join(masks_save_path, f"{base_name}_mask.png"), final_mask)

    print(f"Successfully processed {len(os.listdir(images_save_path))} images.")

# Example Usage:
# preprocess_pipeline('raw_tiffs', 'coord_texts', 'prepared_data')

# %%
## Visualizing Preprocessing

import os
import cv2
import numpy as np
import pandas as pd
from scipy.spatial import Voronoi

def step1_preprocessing(image_dir, text_dir, output_dir, img_size=(512, 512)):
    os.makedirs(output_dir, exist_ok=True)
    images_out = os.path.join(output_dir, "images")
    masks_out = os.path.join(output_dir, "masks")
    os.makedirs(images_out, exist_ok=True)
    os.makedirs(masks_out, exist_ok=True)

    for file_name in os.listdir(image_dir):
        if file_name.lower().endswith('.tiff'):
            # 1. Robust Loading: Use cv2.imread to handle mislabeled JPEGs
            img_path = os.path.join(image_dir, file_name)
            image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
            
            if image is None:
                print(f"Skipping {file_name}: Unsupported format.")
                continue

            h, w = image.shape[:2]

            # 2. Parse your specific text format (id, x, y, tag)
            txt_path = os.path.join(text_dir, file_name.replace('.tiff', '.txt'))
            if not os.path.exists(txt_path): continue

            try:
                # sep='\s+' handles both tabs and spaces
                df = pd.read_csv(txt_path, sep='\s+')
                points = df[['x', 'y']].values
            except Exception: continue

            # 3. Generate 3-Class Mask (0:BG, 1:Interior, 2:Boundary)
            mask = np.zeros((h, w), dtype=np.uint8)

            # Class 2: Boundaries via Voronoi
            if len(points) >= 4:
                vor = Voronoi(points)
                for ridge in vor.ridge_vertices:
                    if -1 not in ridge:
                        v1, v2 = vor.vertices[ridge].astype(int)
                        cv2.line(mask, tuple(v1), tuple(v2), 2, thickness=2)

            # Class 1: Cell Interiors (Dots)
            for pt in points:
                cv2.circle(mask, (int(pt[0]), int(pt[1])), 3, 1, -1)

            # 4. Resize and Save
            final_img = cv2.resize(image, img_size)
            final_mask = cv2.resize(mask, img_size, interpolation=cv2.INTER_NEAREST)

            base = os.path.splitext(file_name)[0]
            cv2.imwrite(os.path.join(images_out, f"{base}.png"), final_img)
            cv2.imwrite(os.path.join(masks_out, f"{base}_mask.png"), final_mask)

    print("Step 1 Complete: Images and Masks prepared.")

img_file = "images_and_labels/71866.tiff"
txt_file = "images_and_labels/71866.txt"
step1_preprocessing(img_file, txt_file, final_mask)
   

    # 4. Plotting
plt.figure(figsize=(15, 5))
    
plt.subplot(1, 3, 1)
plt.title("Original TIFF (Normalized)")
plt.imshow(display_img)
plt.axis('off')
    
plt.subplot(1, 3, 2)
plt.title("Generated Mask (Centers & Boundaries)")
plt.imshow(mask_overlay)
plt.axis('off')
    
plt.subplot(1, 3, 3)
plt.title("Overlay Check")
plt.imshow(blended)
plt.axis('off')
    
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[197], line 65
#      63 img_file = "images_and_labels/71866.tiff"
#      64 txt_file = "images_and_labels/71866.txt"
# ---> 65 step1_preprocessing(img_file, txt_file, final_mask)
#      68     # 4. Plotting
#      69 plt.figure(figsize=(15, 5))
#
# NameError: name 'final_mask' is not defined

# %%
import os
import cv2
import numpy as np
import pandas as pd
from scipy.spatial import Voronoi

def step1_preprocessing(image_dir, text_dir, output_dir, img_size=(256, 256)):
    os.makedirs(output_dir, exist_ok=True)
    images_out = os.path.join(output_dir, "images")
    masks_out = os.path.join(output_dir, "masks")
    os.makedirs(images_out, exist_ok=True)
    os.makedirs(masks_out, exist_ok=True)

    for file_name in os.listdir(image_dir):
        if file_name.lower().endswith('.tiff'):
            # 1. Robust Loading: Use cv2.imread to handle mislabeled JPEGs
            img_path = os.path.join(image_dir, file_name)
            image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
            
            if image is None:
                print(f"Skipping {file_name}: Unsupported format.")
                continue

            h, w = image.shape[:2]

            # 2. Parse your specific text format (id, x, y, tag)
            txt_path = os.path.join(text_dir, file_name.replace('.tiff', '.txt'))
            if not os.path.exists(txt_path): continue

            try:
                # sep='\s+' handles both tabs and spaces
                df = pd.read_csv(txt_path, sep='\s+')
                points = df[['x', 'y']].values
            except Exception: continue

            # 3. Generate 3-Class Mask (0:BG, 1:Interior, 2:Boundary)
            mask = np.zeros((h, w), dtype=np.uint8)

            # Class 2: Boundaries via Voronoi
            if len(points) >= 4:
                vor = Voronoi(points)
                for ridge in vor.ridge_vertices:
                    if -1 not in ridge:
                        v1, v2 = vor.vertices[ridge].astype(int)
                        cv2.line(mask, tuple(v1), tuple(v2), 2, thickness=2)

            # Class 1: Cell Interiors (Dots)
            for pt in points:
                cv2.circle(mask, (int(pt[0]), int(pt[1])), 3, 1, -1)

            # 4. Resize and Save
            final_img = cv2.resize(image, img_size)
            final_mask = cv2.resize(mask, img_size, interpolation=cv2.INTER_NEAREST)

            base = os.path.splitext(file_name)[0]
            cv2.imwrite(os.path.join(images_out, f"{base}.png"), final_img)
            cv2.imwrite(os.path.join(masks_out, f"{base}_mask.png"), final_mask)

    print("Step 1 Complete: Images and Masks prepared.")

# Run: step1_preprocessing('your_images/', 'your_labels/', 'prepared_dataset/')
input_folder = "images_and_labels"
output_folder = "prepared_dataset"

# This will process ALL .tiff files found in "images_and_labels"
step1_preprocessing(
    image_dir=input_folder, 
    text_dir=input_folder, 
    output_dir=output_folder, 
    img_size=(256,256)
)
# Out:
# Step 1 Complete: Images and Masks prepared.

# %%
import os
import cv2
import numpy as np
import pandas as pd
from scipy.spatial import Voronoi

def process_single_sample(img_path, txt_path, output_dir, img_size=(256, 256)):
    os.makedirs(output_dir, exist_ok=True)
    
    # 1. Load Image (Using robust cv2.imread for mislabeled JPEGs)
    image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
    h, w = image.shape[:2]

    # 2. Parse Text File
    df = pd.read_csv(txt_path, sep='\s+')
    points = df[['x', 'y']].values

    # 3. Create Mask
    mask = np.zeros((h, w), dtype=np.uint8)
    if len(points) >= 4:
        vor = Voronoi(points)
        for ridge in vor.ridge_vertices:
            if -1 not in ridge:
                v1, v2 = vor.vertices[ridge].astype(int)
                cv2.line(mask, tuple(v1), tuple(v2), 2, thickness=2)

    for pt in points:
        cv2.circle(mask, (int(pt[0]), int(pt[1])), 3, 1, -1)

    # 4. Resize and Save
    final_img = cv2.resize(image, img_size)
    final_mask = cv2.resize(mask, img_size, interpolation=cv2.INTER_NEAREST)

    cv2.imwrite(os.path.join(output_dir, "71866_prepared.png"), final_img)
    cv2.imwrite(os.path.join(output_dir, "71866_mask.png"), final_mask)
    print("Success: Single sample prepared.")

# Call for your specific file
process_single_sample(
    img_path="images_and_labels/71866.tiff",
    txt_path="images_and_labels/71866.txt",
    output_dir="single_sample_test"
)
# Out:
# Success: Single sample prepared.

# %%
import cv2
import matplotlib.pyplot as plt
import os

def visualize_single_sample(img_path, output_dir):
    
    # --- Load original image ---
    original = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    
    # --- Load processed image and mask ---
    processed_img = cv2.imread(os.path.join(output_dir, "71866_prepared.png"), cv2.IMREAD_GRAYSCALE)
    processed_mask = cv2.imread(os.path.join(output_dir, "71866_mask.png"), cv2.IMREAD_GRAYSCALE)
    
    # Convert mask to binary (if needed)
    processed_mask = (processed_mask > 0).astype("uint8")
    
    # --- Plot ---
    plt.figure(figsize=(14,4))
    
    # 1️⃣ Original image
    plt.subplot(1,4,1)
    plt.imshow(original, cmap='gray')
    plt.title("Original Image")
    plt.axis("off")
    
    # 2️⃣ Preprocessed image
    plt.subplot(1,4,2)
    plt.imshow(processed_img, cmap='gray')
    plt.title("Resized Image (256x256)")
    plt.axis("off")
    
    # 3️⃣ Mask
    plt.subplot(1,4,3)
    plt.imshow(processed_mask, cmap='gray')
    plt.title("Resized Mask")
    plt.axis("off")
    
    # 4️⃣ Overlay
    plt.subplot(1,4,4)
    plt.imshow(processed_img, cmap='gray')
    plt.imshow(processed_mask, cmap='jet', alpha=0.4)
    plt.title("Overlay")
    plt.axis("off")
    
    plt.tight_layout()
    plt.show()

# Call visualization
visualize_single_sample(
    img_path="images_and_labels/71866.tiff",
    output_dir="single_sample_test"
)

import numpy as np
import cv2

mask = cv2.imread("single_sample_test/71866_mask.png", cv2.IMREAD_GRAYSCALE)
print(f"Unique values in mask: {np.unique(mask)}") 
# Expected Output: [0 1 2]
# Out:
# Unique values in mask: [0 1 2]

# %%
# Multiply by 127 to spread 0, 1, 2 across the 0-255 range
viewable_mask = mask * 127 
cv2.imwrite("single_sample_test/71866_mask_VISUAL.png", viewable_mask)
# Out:
# True

# %%
## U-Net Model (Optimized for 256x256)

import tensorflow as tf
from tensorflow.keras import layers, models

def build_unet_256(input_shape=(256, 256, 1), num_classes=3):
    """
    U-Net optimized for 256x256 input.
    Classes: 0 (Background), 1 (Cell Center), 2 (Boundary)
    """
    def conv_block(x, filters):
        x = layers.Conv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)
        x = layers.Conv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)
        return x

    def encoder_block(x, filters):
        skip = conv_block(x, filters)
        pool = layers.MaxPool2D((2, 2))(skip)
        return skip, pool

    def decoder_block(x, skip, filters):
        x = layers.Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(x)
        x = layers.Concatenate()([x, skip])
        x = conv_block(x, filters)
        return x

    inputs = layers.Input(input_shape)

    # Encoder (Downsampling)
    s1, p1 = encoder_block(inputs, 32)  # Starting with 32 filters for efficiency
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    # Bridge
    b1 = conv_block(p4, 512)

    # Decoder (Upsampling)
    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    # Output (Softmax for Multi-class)
    outputs = layers.Conv2D(num_classes, 1, padding="same", activation="softmax")(d4)

    model = models.Model(inputs, outputs, name="Corneal_UNet_256")
    return model

# Initialize and Compile
model = build_unet_256()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "Corneal_UNet_256"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)    │ (None, 256, 256, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_109 (Conv2D)           │ (None, 256, 256, 32)      │             320 │ input_layer_7[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_72        │ (None, 256, 256, 32)      │             128 │ conv2d_109[0][0]           │
# ...

# %%
import numpy as np
import cv2
import os
import tensorflow as tf

# 1. DEFINE the generator (Ensure this is run!)
def train_generator(image_dir, mask_dir, batch_size=8, img_size=(256, 256)):
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
    mask_files = sorted([f for f in os.listdir(mask_dir) if f.endswith('.png')])
    
    if len(image_files) == 0:
        raise ValueError(f"No .png images found in {image_dir}")

    while True:
        idx = np.arange(len(image_files))
        np.random.shuffle(idx)
        
        for i in range(0, len(image_files), batch_size):
            batch_idx = idx[i : i + batch_size]
            batch_imgs = []
            batch_masks = []
            
            for j in batch_idx:
                # Load Image (Input)
                img = cv2.imread(os.path.join(image_dir, image_files[j]), cv2.IMREAD_GRAYSCALE)
                img = cv2.resize(img, img_size) / 255.0
                batch_imgs.append(np.expand_dims(img, axis=-1))
                
                # Load Mask (Label - 0, 1, 2)
                mask = cv2.imread(os.path.join(mask_dir, mask_files[j]), cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, img_size, interpolation=cv2.INTER_NEAREST)
                batch_masks.append(mask)
                
            yield np.array(batch_imgs), np.array(batch_masks)

# --- STEP 1 & 2: Definitions (Run once) ---
model = build_unet_256() 
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 2. SETUP Folders
img_dir = "prepared_dataset/images"
mask_dir = "prepared_dataset/masks"

# 3. INITIALIZE Generator
# Adjust batch_size based on your GPU/RAM (try 4 or 8)
gen = train_generator(img_dir, mask_dir, batch_size=4)

# 4. TRAIN the model
# steps_per_epoch should be (total_images / batch_size)
total_images = len([f for f in os.listdir(img_dir) if f.endswith('.png')])
steps = max(1, total_images // 4)

print(f"Starting training on {total_images} images...")

model.fit(
    gen, 
    steps_per_epoch=steps, 
    epochs=20, 
    verbose=1
)

print("Training finished! Now you can run the 'sliding_window_inference' again.")
# 5. Save the model
model.save("cornea_unet_v1.h5")
# Out:
# Starting training on 385 images...
# Epoch 1/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 228s 2s/step - accuracy: 0.8373 - loss: 0.6398
# Epoch 2/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.8604 - loss: 0.5001
# Epoch 3/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 280s 3s/step - accuracy: 0.8610 - loss: 0.4617
# Epoch 4/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 332s 3s/step - accuracy: 0.8598 - loss: 0.4429
# Epoch 5/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 298s 3s/step - accuracy: 0.8600 - loss: 0.4289
# Epoch 6/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 403s 4s/step - accuracy: 0.8623 - loss: 0.4113
# Epoch 7/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 365s 4s/step - accuracy: 0.8616 - loss: 0.4017
# Epoch 8/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 448s 5s/step - accuracy: 0.8625 - loss: 0.3914
# Epoch 9/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 330s 3s/step - accuracy: 0.8619 - loss: 0.3875
# Epoch 10/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 366s 4s/step - accuracy: 0.8635 - loss: 0.3796
# Epoch 11/20
# ...

# %%
#Sliding Window Inference:This code takes a large .tiff image, breaks it into overlapping chunks, predicts each, and averages the results back into a full mask.

import tensorflow as tf
import numpy as np
import cv2

def sliding_window_inference(image, model, window_size=256, stride=128):
    h, w = image.shape[:2]
    full_prob_mask = np.zeros((h, w, 3), dtype=np.float32)
    count_mask = np.zeros((h, w, 1), dtype=np.float32)

    # 1. Ensure image is float32 and normalized
    img_float = image.astype(np.float32) / 255.0

    # 2. Loop through windows
    for y in range(0, h - window_size + 1, stride):
        for x in range(0, w - window_size + 1, stride):
            # Extract patch
            patch = img_float[y:y+window_size, x:x+window_size]
            
            # Reshape for model (Batch, Height, Width, Channels)
            patch_input = patch.reshape(1, window_size, window_size, 1)
            
            # Use model() instead of model.predict() to avoid retracing warnings
            # convert to tensor for speed
            patch_tensor = tf.convert_to_tensor(patch_input)
            pred = model(patch_tensor, training=False)
            
            # Convert back to numpy and add to full mask
            full_prob_mask[y:y+window_size, x:x+window_size] += pred.numpy()[0]
            count_mask[y:y+window_size, x:x+window_size] += 1

    # 3. Handle edges (areas that might not have been fully covered)
    final_probs = np.divide(full_prob_mask, count_mask, out=np.zeros_like(full_prob_mask), where=count_mask!=0)
    
    return np.argmax(final_probs, axis=-1).astype(np.uint8)

# %%
from skimage import morphology, measure

def post_process_mask(reconstructed_mask):
    """
    Refines the boundary (Class 2) and labels individual cells.
    """
    # 1. Isolate the Cell Interiors (Class 1)
    interiors = (reconstructed_mask == 1).astype(np.uint8)
    
    # 2. Morphological Cleaning: Remove small noise and fill holes
    # Remove objects smaller than 50 pixels (noise)
    cleaned = morphology.remove_small_objects(interiors.astype(bool), min_size=50)
    # Fill small holes inside cells
    cleaned = morphology.remove_small_holes(cleaned, area_threshold=50)
    
    # 3. Connected Component Labeling
    # Assigns a unique ID to every separate cell
    labeled_cells = measure.label(cleaned)
    
    return labeled_cells

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from skimage import color

def visualize_inference_stages(original_img, raw_unet_mask, cleaned_mask, labeled_cells):
    """
    Visualizes the transformation from raw image to labeled cells.
    """
    plt.figure(figsize=(20, 5))

    # Stage 1: Original Input
    plt.subplot(1, 4, 1)
    plt.title("1. Raw Input Image")
    plt.imshow(original_img, cmap='gray')
    plt.axis('off')

    # Stage 2: Sliding Window Output (Raw Probabilities)
    # Using 'jet' to show the 3 classes (BG, Interior, Boundary)
    plt.subplot(1, 4, 2)
    plt.title("2. U-Net Raw Output\n(Sliding Window Reconstructed)")
    plt.imshow(raw_unet_mask, cmap='jet')
    plt.axis('off')

    # Stage 3: Post-Processed Binary Mask
    # Shows the cleaned interiors used for density calculation
    plt.subplot(1, 4, 3)
    plt.title("3. Cleaned Interiors\n(Morphological Filtered)")
    plt.imshow(cleaned_mask, cmap='gray')
    plt.axis('off')

    # Stage 4: Unique Cell Labeling (Instance Segmentation)
    # label2rgb assigns random colors to each unique cell ID
    color_labels = color.label2rgb(labeled_cells, bg_label=0)
    plt.subplot(1, 4, 4)
    plt.title("4. Labeled Cells\n(Ready for Feature Extraction)")
    plt.imshow(color_labels)
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# --- Execution Workflow ---
# 1. reconstructed_mask = sliding_window_inference(image, model)
# 2. labeled_cells = post_process_mask(reconstructed_mask)
# 3. cleaned_mask = (labeled_cells > 0)
# visualize_inference_stages(image, reconstructed_mask, cleaned_mask, labeled_cells)
img_path ="single_sample_test/71866_prepared.png"
image_1 = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
model1 = load_model("cornea_unet_v1.h5")  

reconstructed_mask = sliding_window_inference(image_1,  model1)
print(np.unique(reconstructed_mask))

labeled_cells = post_process_mask(reconstructed_mask)
cleaned_mask =(labeled_cells>0)
visualize_inference_stages(image_1, reconstructed_mask, cleaned_mask, labeled_cells)
# Out:
# [0 1]

# %%
# Create a fake mask with a square in the middle (Class 1) and a line (Class 2)
fake_mask = np.zeros((256, 256), dtype=np.uint8)
cv2.rectangle(fake_mask, (50, 50), (150, 150), 1, -1) # Fake Cell Interior
cv2.rectangle(fake_mask, (48, 48), (152, 152), 2, 2)  # Fake Cell Boundary

# Run your post-processing on this fake data
fake_labeled = post_process_mask(fake_mask)
fake_cleaned = (fake_labeled > 0)

# Visualize - If this works, your plotting code is perfect!
visualize_inference_stages(np.zeros((256,256)), fake_mask, fake_cleaned, fake_labeled)

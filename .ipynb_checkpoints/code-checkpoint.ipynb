# %%
import os
import numpy as np
import pandas as pd
import cv2
from glob import glob
from skimage import measure, morphology
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from scipy.spatial import ConvexHull
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\indhi\\ML_Corneal_Endothellium_Imaging'

# %%
print(image_dir)
# Out:
# images_and_labels/

# %%
len(image_files)
# Out:
# 385

# %%
import os
print(os.path.exists("images/71866.tiff"))
# Out:
# False

# %%
# ---------------- PARAMETERS ----------------
IMG_SIZE = 256 # resizing for unet
PIXEL_TO_MM2 = 0.0001  # adjust for your image calibration
CELL_MIN_SIZE = 50     # min pixels to count as a cell

# %%
import os
import cv2
import numpy as np
import pandas as pd
from scipy.spatial import Voronoi

def step1_preprocessing(image_dir, text_dir, output_dir, img_size=(256, 256)):
    os.makedirs(output_dir, exist_ok=True)
    images_out = os.path.join(output_dir, "images")
    masks_out = os.path.join(output_dir, "masks")
    os.makedirs(images_out, exist_ok=True)
    os.makedirs(masks_out, exist_ok=True)

    for file_name in os.listdir(image_dir):
        if file_name.lower().endswith('.tiff'):
            # 1. Robust Loading: Use cv2.imread to handle mislabeled JPEGs
            img_path = os.path.join(image_dir, file_name)
            image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
            
            if image is None:
                print(f"Skipping {file_name}: Unsupported format.")
                continue

            h, w = image.shape[:2]

            # 2. Parse your specific text format (id, x, y, tag)
            txt_path = os.path.join(text_dir, file_name.replace('.tiff', '.txt'))
            if not os.path.exists(txt_path): continue

            try:
                # sep='\s+' handles both tabs and spaces
                df = pd.read_csv(txt_path, sep='\s+')
                points = df[['x', 'y']].values
            except Exception: continue

            # 3. Generate 3-Class Mask (0:BG, 1:Interior, 2:Boundary)
            mask = np.zeros((h, w), dtype=np.uint8)

            # Class 2: Boundaries via Voronoi
            if len(points) >= 4:
                vor = Voronoi(points)
                for ridge in vor.ridge_vertices:
                    if -1 not in ridge:
                        v1, v2 = vor.vertices[ridge].astype(int)
                        cv2.line(mask, tuple(v1), tuple(v2), 2, thickness=2)

            # Class 1: Cell Interiors (Dots)
            for pt in points:
                cv2.circle(mask, (int(pt[0]), int(pt[1])), 3, 1, -1)

            # 4. Resize and Save
            final_img = cv2.resize(image, img_size)
            final_mask = cv2.resize(mask, img_size, interpolation=cv2.INTER_NEAREST)

            base = os.path.splitext(file_name)[0]
            cv2.imwrite(os.path.join(images_out, f"{base}.png"), final_img)
            cv2.imwrite(os.path.join(masks_out, f"{base}_mask.png"), final_mask)

    print("Step 1 Complete: Images and Masks prepared.")

# Run: step1_preprocessing('your_images/', 'your_labels/', 'prepared_dataset/')
input_folder = "images_and_labels"
output_folder = "prepared_dataset"

# This will process ALL .tiff files found in "images_and_labels"
step1_preprocessing(
    image_dir=input_folder, 
    text_dir=input_folder, 
    output_dir=output_folder, 
    img_size=(256,256)
)
# Out:
# Step 1 Complete: Images and Masks prepared.

# %%
import os
import cv2
import numpy as np
import pandas as pd
from scipy.spatial import Voronoi

def process_single_sample(img_path, txt_path, output_dir, img_size=(256, 256)):
    os.makedirs(output_dir, exist_ok=True)
    
    # 1. Load Image (Using robust cv2.imread for mislabeled JPEGs)
    image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
    h, w = image.shape[:2]

    # 2. Parse Text File
    df = pd.read_csv(txt_path, sep='\s+')
    points = df[['x', 'y']].values

    # 3. Create Mask
    mask = np.zeros((h, w), dtype=np.uint8)
    if len(points) >= 4:
        vor = Voronoi(points)
        for ridge in vor.ridge_vertices:
            if -1 not in ridge:
                v1, v2 = vor.vertices[ridge].astype(int)
                cv2.line(mask, tuple(v1), tuple(v2), 2, thickness=2)

    for pt in points:
        cv2.circle(mask, (int(pt[0]), int(pt[1])), 3, 1, -1)

    # 4. Resize and Save
    final_img = cv2.resize(image, img_size)
    final_mask = cv2.resize(mask, img_size, interpolation=cv2.INTER_NEAREST)

    cv2.imwrite(os.path.join(output_dir, "71866_prepared.png"), final_img)
    cv2.imwrite(os.path.join(output_dir, "71866_mask.png"), final_mask)
    print("Success: Single sample prepared.")

# Call for your specific file
process_single_sample(
    img_path="images_and_labels/71866.tiff",
    txt_path="images_and_labels/71866.txt",
    output_dir="single_sample_test"
)
# Out:
# Success: Single sample prepared.

# %%
import cv2
import matplotlib.pyplot as plt
import os

def visualize_single_sample(img_path, output_dir):
    
    # --- Load original image ---
    original = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    
    # --- Load processed image and mask ---
    processed_img = cv2.imread(os.path.join(output_dir, "71866_prepared.png"), cv2.IMREAD_GRAYSCALE)
    processed_mask = cv2.imread(os.path.join(output_dir, "71866_mask.png"), cv2.IMREAD_GRAYSCALE)
    
    # Convert mask to binary (if needed)
    processed_mask = (processed_mask > 0).astype("uint8")
    
    # --- Plot ---
    plt.figure(figsize=(14,4))
    
    
    # 1️⃣ Original image
    plt.subplot(1,4,1)
    plt.imshow(original, cmap='gray')
    plt.title("Original Image")
    plt.axis("off")
    
    # 2️⃣ Preprocessed image
    plt.subplot(1,4,2)
    plt.imshow(processed_img, cmap='gray')
    plt.title("Resized Image (256x256)")
    plt.axis("off")
    
    # 3️⃣ Mask
    plt.subplot(1,4,3)
    plt.imshow(processed_mask, cmap='gray')
    plt.title("Resized Mask")
    plt.axis("off")
    
    # 4️⃣ Overlay
    plt.subplot(1,4,4)
    plt.imshow(processed_img, cmap='gray')
    plt.imshow(processed_mask, cmap='jet', alpha=0.4)
    plt.title("Overlay")
    plt.axis("off")
    
    plt.tight_layout()
    plt.show()

# Call visualization
visualize_single_sample(
    img_path="images_and_labels/71866.tiff",
    output_dir="single_sample_test"
)

import numpy as np
import cv2

mask = cv2.imread("single_sample_test/71866_mask.png", cv2.IMREAD_GRAYSCALE)
print(f"Unique values in mask: {np.unique(mask)}") 
# Expected Output: [0 1 2]
# Out:
# Unique values in mask: [0 1 2]

# %%
# Multiply by 127 to spread 0, 1, 2 across the 0-255 range
viewable_mask = mask * 127 
cv2.imwrite("single_sample_test/71866_mask_VISUAL.png", viewable_mask)
# Out:
# True

# %%
## U-Net Model (Optimized for 256x256)

import tensorflow as tf
from tensorflow.keras import layers, models

def build_unet_256(input_shape=(256, 256, 1), num_classes=3):
    """
    U-Net optimized for 256x256 input.
    Classes: 0 (Background), 1 (Cell Center), 2 (Boundary)
    """
    def conv_block(x, filters):
        x = layers.Conv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)
        x = layers.Conv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)
        return x

    def encoder_block(x, filters):
        skip = conv_block(x, filters)
        pool = layers.MaxPool2D((2, 2))(skip)
        return skip, pool

    def decoder_block(x, skip, filters):
        x = layers.Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(x)
        x = layers.Concatenate()([x, skip])
        x = conv_block(x, filters)
        return x

    inputs = layers.Input(input_shape)

    # Encoder (Downsampling)
    s1, p1 = encoder_block(inputs, 32)  # Starting with 32 filters for efficiency
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    # Bridge
    b1 = conv_block(p4, 512)

    # Decoder (Upsampling)
    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    # Output (Softmax for Multi-class)
    outputs = layers.Conv2D(num_classes, 1, padding="same", activation="softmax")(d4)

    model = models.Model(inputs, outputs, name="Corneal_UNet_256")
    return model

# Initialize and Compile
model = build_unet_256()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "Corneal_UNet_256"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_19 (InputLayer)   │ (None, 256, 256, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_337 (Conv2D)           │ (None, 256, 256, 32)      │             320 │ input_layer_19[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_288       │ (None, 256, 256, 32)      │             128 │ conv2d_337[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_252 (Activation)   │ (None, 256, 256, 32)      │               0 │ batch_normalization_288[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_338 (Conv2D)           │ (None, 256, 256, 32)      │           9,248 │ activation_252[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_289       │ (None, 256, 256, 32)      │             128 │ conv2d_338[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_253 (Activation)   │ (None, 256, 256, 32)      │               0 │ batch_normalization_289[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_70              │ (None, 128, 128, 32)      │               0 │ activation_253[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_339 (Conv2D)           │ (None, 128, 128, 64)      │          18,496 │ max_pooling2d_70[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_290       │ (None, 128, 128, 64)      │             256 │ conv2d_339[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_254 (Activation)   │ (None, 128, 128, 64)      │               0 │ batch_normalization_290[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_340 (Conv2D)           │ (None, 128, 128, 64)      │          36,928 │ activation_254[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_291       │ (None, 128, 128, 64)      │             256 │ conv2d_340[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_255 (Activation)   │ (None, 128, 128, 64)      │               0 │ batch_normalization_291[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_71              │ (None, 64, 64, 64)        │               0 │ activation_255[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_341 (Conv2D)           │ (None, 64, 64, 128)       │          73,856 │ max_pooling2d_71[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_292       │ (None, 64, 64, 128)       │             512 │ conv2d_341[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_256 (Activation)   │ (None, 64, 64, 128)       │               0 │ batch_normalization_292[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_342 (Conv2D)           │ (None, 64, 64, 128)       │         147,584 │ activation_256[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_293       │ (None, 64, 64, 128)       │             512 │ conv2d_342[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_257 (Activation)   │ (None, 64, 64, 128)       │               0 │ batch_normalization_293[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_72              │ (None, 32, 32, 128)       │               0 │ activation_257[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_343 (Conv2D)           │ (None, 32, 32, 256)       │         295,168 │ max_pooling2d_72[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_294       │ (None, 32, 32, 256)       │           1,024 │ conv2d_343[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_258 (Activation)   │ (None, 32, 32, 256)       │               0 │ batch_normalization_294[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_344 (Conv2D)           │ (None, 32, 32, 256)       │         590,080 │ activation_258[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_295       │ (None, 32, 32, 256)       │           1,024 │ conv2d_344[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_259 (Activation)   │ (None, 32, 32, 256)       │               0 │ batch_normalization_295[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_73              │ (None, 16, 16, 256)       │               0 │ activation_259[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_345 (Conv2D)           │ (None, 16, 16, 512)       │       1,180,160 │ max_pooling2d_73[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_296       │ (None, 16, 16, 512)       │           2,048 │ conv2d_345[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_260 (Activation)   │ (None, 16, 16, 512)       │               0 │ batch_normalization_296[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_346 (Conv2D)           │ (None, 16, 16, 512)       │       2,359,808 │ activation_260[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_297       │ (None, 16, 16, 512)       │           2,048 │ conv2d_346[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_261 (Activation)   │ (None, 16, 16, 512)       │               0 │ batch_normalization_297[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_64           │ (None, 32, 32, 256)       │         524,544 │ activation_261[0][0]       │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_70 (Concatenate)  │ (None, 32, 32, 512)       │               0 │ conv2d_transpose_64[0][0], │
# │                               │                           │                 │ activation_259[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_347 (Conv2D)           │ (None, 32, 32, 256)       │       1,179,904 │ concatenate_70[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_298       │ (None, 32, 32, 256)       │           1,024 │ conv2d_347[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_262 (Activation)   │ (None, 32, 32, 256)       │               0 │ batch_normalization_298[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_348 (Conv2D)           │ (None, 32, 32, 256)       │         590,080 │ activation_262[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_299       │ (None, 32, 32, 256)       │           1,024 │ conv2d_348[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_263 (Activation)   │ (None, 32, 32, 256)       │               0 │ batch_normalization_299[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_65           │ (None, 64, 64, 128)       │         131,200 │ activation_263[0][0]       │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_71 (Concatenate)  │ (None, 64, 64, 256)       │               0 │ conv2d_transpose_65[0][0], │
# │                               │                           │                 │ activation_257[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_349 (Conv2D)           │ (None, 64, 64, 128)       │         295,040 │ concatenate_71[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_300       │ (None, 64, 64, 128)       │             512 │ conv2d_349[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_264 (Activation)   │ (None, 64, 64, 128)       │               0 │ batch_normalization_300[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_350 (Conv2D)           │ (None, 64, 64, 128)       │         147,584 │ activation_264[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_301       │ (None, 64, 64, 128)       │             512 │ conv2d_350[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_265 (Activation)   │ (None, 64, 64, 128)       │               0 │ batch_normalization_301[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_66           │ (None, 128, 128, 64)      │          32,832 │ activation_265[0][0]       │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_72 (Concatenate)  │ (None, 128, 128, 128)     │               0 │ conv2d_transpose_66[0][0], │
# │                               │                           │                 │ activation_255[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_351 (Conv2D)           │ (None, 128, 128, 64)      │          73,792 │ concatenate_72[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_302       │ (None, 128, 128, 64)      │             256 │ conv2d_351[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_266 (Activation)   │ (None, 128, 128, 64)      │               0 │ batch_normalization_302[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_352 (Conv2D)           │ (None, 128, 128, 64)      │          36,928 │ activation_266[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_303       │ (None, 128, 128, 64)      │             256 │ conv2d_352[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_267 (Activation)   │ (None, 128, 128, 64)      │               0 │ batch_normalization_303[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_67           │ (None, 256, 256, 32)      │           8,224 │ activation_267[0][0]       │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_73 (Concatenate)  │ (None, 256, 256, 64)      │               0 │ conv2d_transpose_67[0][0], │
# │                               │                           │                 │ activation_253[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_353 (Conv2D)           │ (None, 256, 256, 32)      │          18,464 │ concatenate_73[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_304       │ (None, 256, 256, 32)      │             128 │ conv2d_353[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_268 (Activation)   │ (None, 256, 256, 32)      │               0 │ batch_normalization_304[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_354 (Conv2D)           │ (None, 256, 256, 32)      │           9,248 │ activation_268[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_305       │ (None, 256, 256, 32)      │             128 │ conv2d_354[0][0]           │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_269 (Activation)   │ (None, 256, 256, 32)      │               0 │ batch_normalization_305[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_355 (Conv2D)           │ (None, 256, 256, 3)       │              99 │ activation_269[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 7,771,363 (29.65 MB)
#  Trainable params: 7,765,475 (29.62 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
import numpy as np
import cv2
import os
import tensorflow as tf

# 1. DEFINE the generator (Ensure this is run!)
def train_generator(image_dir, mask_dir, batch_size=8, img_size=(256, 256)):
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
    mask_files = sorted([f for f in os.listdir(mask_dir) if f.endswith('.png')])
    
    if len(image_files) == 0:
        raise ValueError(f"No .png images found in {image_dir}")

    while True:
        idx = np.arange(len(image_files))
        np.random.shuffle(idx)
        
        for i in range(0, len(image_files), batch_size):
            batch_idx = idx[i : i + batch_size]
            batch_imgs = []
            batch_masks = []
            
            for j in batch_idx:
                # Load Image (Input)
                img = cv2.imread(os.path.join(image_dir, image_files[j]), cv2.IMREAD_GRAYSCALE)
                img = cv2.resize(img, img_size) / 255.0
                batch_imgs.append(np.expand_dims(img, axis=-1))
                
                # Load Mask (Label - 0, 1, 2)
                mask = cv2.imread(os.path.join(mask_dir, mask_files[j]), cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, img_size, interpolation=cv2.INTER_NEAREST)
                batch_masks.append(mask)
                
            yield np.array(batch_imgs), np.array(batch_masks)

# --- STEP 1 & 2: Definitions (Run once) ---
model = build_unet_256() 
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 2. SETUP Folders
img_dir = "prepared_dataset/images"
mask_dir = "prepared_dataset/masks"

# 3. INITIALIZE Generator
# Adjust batch_size based on your GPU/RAM (try 4 or 8)
gen = train_generator(img_dir, mask_dir, batch_size=4)

# 4. TRAIN the model
# steps_per_epoch should be (total_images / batch_size)
total_images = len([f for f in os.listdir(img_dir) if f.endswith('.png')])
steps = max(1, total_images // 4)

print(f"Starting training on {total_images} images...")

model.fit(
    gen, 
    steps_per_epoch=steps, 
    epochs=20, 
    verbose=1
)

print("Training finished! Now you can run the 'sliding_window_inference' again.")
# 5. Save the model
model.save("cornea_unet_v1.keras")
print("Model saved in native Keras format!")
# Out:
# Starting training on 385 images...
# Epoch 1/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 225s 2s/step - accuracy: 0.8325 - loss: 0.5381
# Epoch 2/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.8608 - loss: 0.4387
# Epoch 3/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.8615 - loss: 0.4141
# Epoch 4/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 237s 2s/step - accuracy: 0.8589 - loss: 0.3980
# Epoch 5/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.8616 - loss: 0.3824
# Epoch 6/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.8636 - loss: 0.3717
# Epoch 7/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 235s 2s/step - accuracy: 0.8606 - loss: 0.3748
# Epoch 8/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 294s 3s/step - accuracy: 0.8643 - loss: 0.3660
# Epoch 9/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 247s 3s/step - accuracy: 0.8648 - loss: 0.3588
# Epoch 10/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 250s 3s/step - accuracy: 0.8645 - loss: 0.3579
# Epoch 11/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 257s 3s/step - accuracy: 0.8645 - loss: 0.3536
# Epoch 12/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 282s 3s/step - accuracy: 0.8697 - loss: 0.3429
# Epoch 13/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.8683 - loss: 0.3439
# Epoch 14/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.8673 - loss: 0.3451
# Epoch 15/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 249s 3s/step - accuracy: 0.8698 - loss: 0.3371
# Epoch 16/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 248s 3s/step - accuracy: 0.8715 - loss: 0.3344
# Epoch 17/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - accuracy: 0.8717 - loss: 0.3322
# Epoch 18/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - accuracy: 0.8709 - loss: 0.3333
# Epoch 19/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 250s 3s/step - accuracy: 0.8718 - loss: 0.3305
# Epoch 20/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.8761 - loss: 0.3195
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training finished! Now you can run the 'sliding_window_inference' again.

# %%
#Sliding Window Inference:This code takes a large .tiff image, breaks it into overlapping chunks, predicts each, and averages the results back into a full mask.

import tensorflow as tf
import numpy as np
import cv2
## For 256×256 images, this function effectively does full-image inference once.
# For larger images (>256×256), sliding window ensures accurate predictions and smooth overlapping masks.

def sliding_window_inference(image, model, window_size=256, stride=128):
    h, w = image.shape[:2]
    full_prob_mask = np.zeros((h, w, 3), dtype=np.float32)
    count_mask = np.zeros((h, w, 1), dtype=np.float32)

    # 1. Ensure image is float32 and normalized
    img_float = image.astype(np.float32) / 255.0

    # 2. Loop through windows
    for y in range(0, h - window_size + 1, stride):
        for x in range(0, w - window_size + 1, stride):
            # Extract patch
            patch = img_float[y:y+window_size, x:x+window_size]
            
            # Reshape for model (Batch, Height, Width, Channels)
            patch_input = patch.reshape(1, window_size, window_size, 1)
            
            # Use model() instead of model.predict() to avoid retracing warnings
            # convert to tensor for speed
            patch_tensor = tf.convert_to_tensor(patch_input)
            pred = model(patch_tensor, training=False)
            
            # Convert back to numpy and add to full mask
            full_prob_mask[y:y+window_size, x:x+window_size] += pred.numpy()[0]
            count_mask[y:y+window_size, x:x+window_size] += 1

    # 3. Handle edges (areas that might not have been fully covered)
    final_probs = np.divide(full_prob_mask, count_mask, out=np.zeros_like(full_prob_mask), where=count_mask!=0)
    
    return np.argmax(final_probs, axis=-1).astype(np.uint8)

# %%
import numpy as np
import cv2
from skimage import morphology, measure, segmentation
from scipy import ndimage as ndi

def post_process_mask_v3(reconstructed_mask):
    # 1. Get the "Seeds" (The green/yellow dots in your Plot 2)
    # These are likely Class 1
    seeds = (reconstructed_mask == 1).astype(np.uint8)
    
    # 2. Get the "Walls" (The red lines in your Plot 2)
    # These are likely Class 2
    walls = (reconstructed_mask == 2).astype(np.uint8)
    
    # 3. Create the "Interior Mask" (Everything that isn't a wall or background)
    # This combines interiors and the space between them
    cell_bodies = (reconstructed_mask > 0).astype(np.uint8)
    
    # 4. Clean the seeds (Ensure they are distinct dots)
    seeds = morphology.remove_small_objects(seeds.astype(bool), min_size=2)
    markers = measure.label(seeds)
    
    # 5. Use Watershed to expand seeds until they hit the red walls
    # This prevents cells from merging and fills the "dark" centers
    labels = segmentation.watershed(walls, markers, mask=cell_bodies)
    
    return labels

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from skimage import color
from tensorflow.keras.models import load_model

def visualize_inference_stages(original_img, raw_unet_mask, cleaned_mask, labeled_cells):
    """
    Visualizes the transformation from raw image to labeled cells.
    """
    plt.figure(figsize=(20, 5))

    # Stage 1: Original Input
    plt.subplot(1, 4, 1)
    plt.title("1. Raw Input Image")
    plt.imshow(original_img, cmap='gray')
    plt.axis('off')

    # Stage 2: Sliding Window Output (Raw Probabilities)
    # Using 'jet' to show the 3 classes (BG, Interior, Boundary)
    plt.subplot(1, 4, 2)
    plt.title("2. U-Net Raw Output\n(Sliding Window Reconstructed)")
    plt.imshow(raw_unet_mask, cmap='jet')
    plt.axis('off')

    # Stage 3: Post-Processed Binary Mask
    # Shows the cleaned interiors used for density calculation
    plt.subplot(1, 4, 3)
    plt.title("3. Cleaned Interiors\n(Morphological Filtered)")
    plt.imshow(cleaned_mask, cmap='gray')
    plt.axis('off')

    # Stage 4: Unique Cell Labeling (Instance Segmentation)
    # label2rgb assigns random colors to each unique cell ID
    color_labels = color.label2rgb(labeled_cells, bg_label=0)
    plt.subplot(1, 4, 4)
    plt.title("4. Labeled Cells\n(Ready for Feature Extraction)")
    plt.imshow(color_labels)
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# --- Execution Workflow ---
# 1. reconstructed_mask = sliding_window_inference(image, model)
# 2. labeled_cells = post_process_mask(reconstructed_mask)
# 3. cleaned_mask = (labeled_cells > 0)
# visualize_inference_stages(image, reconstructed_mask, cleaned_mask, labeled_cells)
img_path ="single_sample_test/71866_prepared.png"
image_1 = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)


# Load the brain (skip model.fit after this)
model1 = load_model("cornea_unet_v1.keras")
print("Model loaded successfully!")



reconstructed_mask = sliding_window_inference(image_1,  model1)
print(np.unique(reconstructed_mask))

labeled_cells =post_process_mask_v3(reconstructed_mask)
cleaned_mask =(labeled_cells>0)
visualize_inference_stages(image_1, reconstructed_mask, cleaned_mask, labeled_cells)
# Out:
# Model loaded successfully!
# [0 1 2]

# %%
# another example 
process_single_sample(
    img_path="images_and_labels/71866.tiff",
    txt_path="images_and_labels/71866.txt",
    output_dir="single_sample_test"
)




img_path ="single_sample_test/71866_prepared.png"
image_1 = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)


# Load the brain (skip model.fit after this)
model1 = load_model("cornea_unet_v1.keras")
print("Model loaded successfully!")



reconstructed_mask = sliding_window_inference(image_1,  model1)
print(np.unique(reconstructed_mask))

labeled_cells =post_process_mask_v3(reconstructed_mask)
cleaned_mask =(labeled_cells>0)
visualize_inference_stages(image_1, reconstructed_mask, cleaned_mask, labeled_cells)

# %%
# Create a fake mask with a square in the middle (Class 1) and a line (Class 2)
fake_mask = np.zeros((256, 256), dtype=np.uint8)
cv2.rectangle(fake_mask, (50, 50), (150, 150), 1, -1) # Fake Cell Interior
cv2.rectangle(fake_mask, (48, 48), (152, 152), 2, 2)  # Fake Cell Boundary

# Run your post-processing on this fake data
fake_labeled = post_process_mask(fake_mask)
fake_cleaned = (fake_labeled > 0)

# Visualize - If this works, your plotting code is perfect!
visualize_inference_stages(np.zeros((256,256)), fake_mask, fake_cleaned, fake_labeled)

# %%
# Out:
# --- Clinical Report ---
# Total Cells: 235
# ECD (cells/mm²): 943.02
# CV: 0.309
# Hexagonality (%): 0.0
# Status: Abnormal

# %%
#Morphometric Feature Extraction

#The pixel-to-mm conversion for a specular microscope - 0.00115 mm/pixel
import numpy as np
import pandas as pd
from skimage.measure import regionprops

def get_clinical_report(labeled_cells, pixel_to_mm= 0.00115):
    """
    Calculates ECD, CV, and Hexagonality from the uniquely labeled cell mask.
    Note: pixel_to_mm must be calibrated to specular microscope.
    """
    # 1. Extract properties for each unique cell
    props = regionprops(labeled_cells)
    # FIX: Return a dictionary with zeros instead of a string error
    if len(props) == 0:
        return {
            "Total Cells Counted": 0,
            "ECD (cells/mm²)": 0,
            "CV (Polymegathism)": 0,
            "Hexagonality % (Pleomorphism)": 0,
            "Clinical Status": "INVALID/NO CELLS"
        }

    # 2. Calculate Individual Cell Areas (in mm^2)
    # Area_mm2 = Area_pixels * (pixel_to_mm^2)
    areas_mm2 = [p.area * (pixel_to_mm**2) for p in props]
    
    # --- Metric 1: Endothelial Cell Density (ECD) ---
    # Formula: Number of cells / Total scanned area in mm^2
    h, w = labeled_cells.shape
    total_scanned_area_mm2 = (h * pixel_to_mm) * (w * pixel_to_mm)
    ecd = len(props) / total_scanned_area_mm2

    # --- Metric 2: Coefficient of Variation (CV) ---
    # Measures Polymegathism (Size variability)
    # Formula: Standard Deviation of areas / Mean area
    mean_area = np.mean(areas_mm2)
    std_area = np.std(areas_mm2)
    cv = std_area / mean_area if mean_area > 0 else 0

    # --- Metric 3: Hexagonality (H) ---
    # Measures Pleomorphism (Shape regularity)
    hex_count = 0
    for p in props:
        # 1. Get the coordinates of the cell boundary
        # We need a 2D array of [x, y] for cv2.approxPolyDP
        contour = np.array(p.coords).astype(np.int32)
        
        # 2. Approximate the shape into a polygon
        # epsilon is the precision: 3-5% of the perimeter is a good range
        epsilon = 0.04 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)
        
        # 3. If the simplified polygon has 6 vertices, it's hexagonal
        if len(approx) == 6:
            hex_count += 1
            
    hexagonality  =  (hex_count / len(props)) * 100
   
    # --- Step 5: Final Classification ---
    # Normal thresholds: ECD > 2000, CV < 0.40, H > 50%
    is_abnormal = (ecd < 2000) or (cv > 0.40) or (hexagonality < 50)
    
    return {
        "Total Cells Counted": len(props),
        "ECD (cells/mm²)": round(ecd, 2),
        "CV (Polymegathism)": round(cv, 3),
        "Hexagonality % (Pleomorphism)": round(hexagonality, 2),
        "Clinical Status": "ABNORMAL" if is_abnormal else "NORMAL"
    }

# --- Execution ---
report = get_clinical_report(labeled_cells)

print("\n" + "="*30)
print("FINAL CLINICAL REPORT")
print("="*30)
for key, value in report.items():
    print(f"{key:28}: {value}")
print("="*30)
# Out:
# ==============================
# FINAL CLINICAL REPORT
# ==============================
# Total Cells Counted         : 235
# ECD (cells/mm²)             : 2711.39
# CV (Polymegathism)          : 0.309
# Hexagonality % (Pleomorphism): 23.4
# Clinical Status             : ABNORMAL
# ==============================

# %%
txt_path = "images_and_labels/71866.txt"

df = pd.read_csv(txt_path, sep="\t")

num_annotations = len(df)

print("Number of annotated cells:", num_annotations)
# Out:
# Number of annotated cells: 266

# %%
from PIL import Image
img = Image.open("images_and_labels/71866.tiff")
# returns pixels per inch (DPI); divide 25.4 by this to get mm/pixel
print(img.info.get('dpi'))
# Out:
# (1, 1)

# %%
import os
import cv2
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model

# --- Initialization ---
model = load_model("cornea_unet_v1.keras")
pixel_to_mm = 0.00115  # Update this to camera's actual calibration
input_dir = "images_and_labels/"
results = []

def process_image(img_path):
    # 1. Load and Segment
    image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if image is None: return None
    
    # 2. Sliding Window Inference
    mask = sliding_window_inference(image, model)
    
    # 3. Post-Processing
    labeled = post_process_mask_v3(mask)
    
    # 4. Feature Extraction
    report = get_clinical_report(labeled, pixel_to_mm)
    return report

# --- Main Loop ---
print(f"Starting batch processing in {input_dir}...")

for filename in os.listdir(input_dir):
    if filename.endswith(".tiff"):
        print(f"Processing: {filename}")
        img_full_path = os.path.join(input_dir, filename)
        
        try:
            metrics = process_image(img_full_path)
            if metrics:
                metrics['Filename'] = filename
                results.append(metrics)
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# --- Save to Excel ---
df = pd.DataFrame(results)
# Reorder columns to put Filename first
cols = ['Filename'] + [c for c in df.columns if c != 'Filename']
df = df[cols]
# Out:
# C:\Users\indhi\cornea_env\lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 84 variables whereas the saved optimizer has 166 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Starting batch processing in images_and_labels/...
# Processing: 71866.tiff
# Processing: 71867.tiff
# Processing: 71868.tiff
# Processing: 71869.tiff
# Processing: 71870.tiff
# Processing: 71871.tiff
# Processing: 71872.tiff
# Processing: 71873.tiff
# Processing: 71874.tiff
# Processing: 71875.tiff
# Processing: 71876.tiff
# Processing: 71877.tiff
# Processing: 71878.tiff
# Processing: 71879.tiff
# Processing: 71880.tiff
# Processing: 71881.tiff
# Processing: 71882.tiff
# Processing: 71883.tiff
# Processing: 71884.tiff
# Processing: 71885.tiff
# Processing: 71886.tiff
# Processing: 71887.tiff
# Processing: 71888.tiff
# Processing: 71889.tiff
# Processing: 71890.tiff
# Processing: 71891.tiff
# Processing: 71892.tiff
# Processing: 71893.tiff
# Processing: 71894.tiff
# Processing: 71895.tiff
# Processing: 71896.tiff
# Processing: 71897.tiff
# Processing: 71898.tiff
# Processing: 71899.tiff
# Processing: 71900.tiff
# Processing: 71901.tiff
# Processing: 71902.tiff
# Processing: 71903.tiff
# Processing: 71904.tiff
# Processing: 71905.tiff
# Processing: 71906.tiff
# Processing: 71907.tiff
# Processing: 71908.tiff
# Processing: 71909.tiff
# Processing: 71910.tiff
# Processing: 71911.tiff
# Processing: 71912.tiff
# Processing: 71913.tiff
# Processing: 71914.tiff
# Processing: 71915.tiff
# Processing: 71916.tiff
# Processing: 71917.tiff
# Processing: 71918.tiff
# Processing: 71919.tiff
# Processing: 71920.tiff
# Processing: 71921.tiff
# Processing: 71922.tiff
# Processing: 71923.tiff
# Processing: 71924.tiff
# Processing: 71925.tiff
# Processing: 71926.tiff
# Processing: 71927.tiff
# Processing: 71928.tiff
# Processing: 71929.tiff
# Processing: 71930.tiff
# Processing: 71931.tiff
# Processing: 71932.tiff
# Processing: 71933.tiff
# Processing: 71934.tiff
# Processing: 71935.tiff
# Processing: 71936.tiff
# Processing: 71937.tiff
# Processing: 71938.tiff
# Processing: 71939.tiff
# Processing: 71940.tiff
# Processing: 71941.tiff
# Processing: 71942.tiff
# Processing: 71943.tiff
# Processing: 71944.tiff
# Processing: 71945.tiff
# Processing: 71946.tiff
# Processing: 71947.tiff
# Processing: 71948.tiff
# Processing: 71949.tiff
# Processing: 71950.tiff
# Processing: 71951.tiff
# Processing: 71952.tiff
# Processing: 71953.tiff
# Processing: 71954.tiff
# Processing: 71955.tiff
# Processing: 71956.tiff
# Processing: 71957.tiff
# Processing: 71958.tiff
# Processing: 71959.tiff
# Processing: 71960.tiff
# Processing: 71961.tiff
# Processing: 71962.tiff
# Processing: 71963.tiff
# Processing: 71964.tiff
# Processing: 71965.tiff
# Processing: 71966.tiff
# Processing: 71967.tiff
# Processing: 71968.tiff
# Processing: 71969.tiff
# Processing: 71970.tiff
# Processing: 71971.tiff
# Processing: 71972.tiff
# Processing: 71973.tiff
# Processing: 71974.tiff
# Processing: 71975.tiff
# Processing: 71976.tiff
# Processing: 71977.tiff
# Processing: 71978.tiff
# Processing: 71979.tiff
# Processing: 71980.tiff
# Processing: 71981.tiff
# Processing: 71982.tiff
# Processing: 71983.tiff
# Processing: 71984.tiff
# Processing: 71985.tiff
# Processing: 71986.tiff
# Processing: 71987.tiff
# Processing: 71988.tiff
# Processing: 71989.tiff
# Processing: 71990.tiff
# Processing: 71991.tiff
# Processing: 71992.tiff
# Processing: 71993.tiff
# Processing: 71994.tiff
# Processing: 71995.tiff
# Processing: 71996.tiff
# Processing: 71997.tiff
# Processing: 71998.tiff
# Processing: 71999.tiff
# Processing: 72000.tiff
# Processing: 72001.tiff
# Processing: 72002.tiff
# Processing: 72003.tiff
# Processing: 72004.tiff
# Processing: 72005.tiff
# Processing: 72006.tiff
# Processing: 72007.tiff
# Processing: 72008.tiff
# Processing: 72009.tiff
# Processing: 72010.tiff
# Processing: 72011.tiff
# Processing: 72012.tiff
# Processing: 72013.tiff
# Processing: 72014.tiff
# Processing: 72015.tiff
# Processing: 72016.tiff
# Processing: 72017.tiff
# Processing: 72018.tiff
# Processing: 72019.tiff
# Processing: 72020.tiff
# Processing: 72021.tiff
# Processing: 72022.tiff
# Processing: 72023.tiff
# Processing: 72024.tiff
# Processing: 72025.tiff
# Processing: 72026.tiff
# Processing: 72027.tiff
# Processing: 72028.tiff
# Processing: 72029.tiff
# Processing: 72030.tiff
# Processing: 72031.tiff
# Processing: 72032.tiff
# Processing: 72033.tiff
# Processing: 72034.tiff
# Processing: 72035.tiff
# Processing: 72036.tiff
# Processing: 72037.tiff
# Processing: 72038.tiff
# Processing: 72039.tiff
# Processing: 72040.tiff
# Processing: 72041.tiff
# Processing: 72042.tiff
# Processing: 72043.tiff
# Processing: 72044.tiff
# Processing: 72045.tiff
# Processing: 72046.tiff
# Processing: 72047.tiff
# Processing: 72048.tiff
# Processing: 72049.tiff
# Processing: 72050.tiff
# Processing: 72051.tiff
# Processing: 72052.tiff
# Processing: 72053.tiff
# Processing: 72054.tiff
# Processing: 72055.tiff
# Processing: 72056.tiff
# Processing: 72057.tiff
# Processing: 72058.tiff
# Processing: 72059.tiff
# Processing: 72060.tiff
# Processing: 72061.tiff
# Processing: 72062.tiff
# Processing: 72063.tiff
# Processing: 72064.tiff
# Processing: 72065.tiff
# Processing: 72066.tiff
# Processing: 72067.tiff
# Processing: 72203.tiff
# Processing: 72204.tiff
# Processing: 72205.tiff
# Processing: 72206.tiff
# Processing: 72207.tiff
# Processing: 72208.tiff
# Processing: 72209.tiff
# Processing: 72210.tiff
# Processing: 72211.tiff
# Processing: 72212.tiff
# Processing: 72213.tiff
# Processing: 72214.tiff
# Processing: 72215.tiff
# Processing: 72216.tiff
# Processing: 72217.tiff
# Processing: 72218.tiff
# Processing: 72219.tiff
# Processing: 72220.tiff
# Processing: 72221.tiff
# Processing: 72222.tiff
# Processing: 72223.tiff
# Processing: 72224.tiff
# Processing: 72225.tiff
# Processing: 72226.tiff
# Processing: 72227.tiff
# Processing: 72228.tiff
# Processing: 72229.tiff
# Processing: 72230.tiff
# Processing: 72231.tiff
# Processing: 72232.tiff
# Processing: 72233.tiff
# Processing: 72234.tiff
# Processing: 72235.tiff
# Processing: 72236.tiff
# Processing: 72237.tiff
# Processing: 72238.tiff
# Processing: 72239.tiff
# Processing: 72240.tiff
# Processing: 72241.tiff
# Processing: 72242.tiff
# Processing: 72243.tiff
# Processing: 72244.tiff
# Processing: 72245.tiff
# Processing: 72246.tiff
# Processing: 72247.tiff
# Processing: 72248.tiff
# Processing: 72249.tiff
# Processing: 72250.tiff
# Processing: 72251.tiff
# Processing: 72252.tiff
# Processing: 72253.tiff
# Processing: 72254.tiff
# Processing: 72255.tiff
# Processing: 72256.tiff
# Processing: 72257.tiff
# Processing: 72258.tiff
# Processing: 72259.tiff
# Processing: 72260.tiff
# Processing: 72261.tiff
# Processing: 72262.tiff
# Processing: 72263.tiff
# Processing: 72264.tiff
# Processing: 72265.tiff
# Processing: 72266.tiff
# Processing: 72267.tiff
# Processing: 72268.tiff
# Processing: 72269.tiff
# Processing: 72270.tiff
# Processing: 72271.tiff
# Processing: 72272.tiff
# Processing: 72273.tiff
# Processing: 72274.tiff
# Processing: 72275.tiff
# Processing: 72276.tiff
# Processing: 72277.tiff
# Processing: 72278.tiff
# Processing: 72279.tiff
# Processing: 72280.tiff
# Processing: 72281.tiff
# Processing: 72282.tiff
# Processing: 72283.tiff
# Processing: 72284.tiff
# Processing: 72285.tiff
# Processing: 72286.tiff
# Processing: 72287.tiff
# Processing: 72288.tiff
# Processing: 72289.tiff
# Processing: 72290.tiff
# Processing: 72291.tiff
# Processing: 72292.tiff
# Processing: 72293.tiff
# Processing: 72294.tiff
# Processing: 72295.tiff
# Processing: 72296.tiff
# Processing: 72297.tiff
# Processing: 72298.tiff
# Processing: 72299.tiff
# Processing: 72300.tiff
# Processing: 72301.tiff
# Processing: 72302.tiff
# Processing: 72303.tiff
# Processing: 72304.tiff
# Processing: 72305.tiff
# Processing: 72306.tiff
# Processing: 72307.tiff
# Processing: 72308.tiff
# Processing: 72309.tiff
# Processing: 72310.tiff
# Processing: 72311.tiff
# Processing: 72312.tiff
# Processing: 72313.tiff
# Processing: 72314.tiff
# Processing: 72315.tiff
# Processing: 72316.tiff
# Processing: 72317.tiff
# Processing: 72318.tiff
# Processing: 72319.tiff
# Processing: 72320.tiff
# Processing: 72321.tiff
# Processing: 72322.tiff
# Processing: 72323.tiff
# Processing: 72324.tiff
# Processing: 72325.tiff
# Processing: 72326.tiff
# Processing: 72327.tiff
# Processing: 72328.tiff
# Processing: 72329.tiff
# Processing: 72330.tiff
# Processing: 72331.tiff
# Processing: 72332.tiff
# Processing: 72333.tiff
# Processing: 72334.tiff
# Processing: 72335.tiff
# Processing: 72336.tiff
# Processing: 72337.tiff
# Processing: 72338.tiff
# Processing: 72339.tiff
# Processing: 72340.tiff
# Processing: 72341.tiff
# Processing: 72342.tiff
# Processing: 72343.tiff
# Processing: 72344.tiff
# Processing: 72345.tiff
# Processing: 72346.tiff
# Processing: 72347.tiff
# Processing: 72348.tiff
# Processing: 72349.tiff
# Processing: 72350.tiff
# Processing: 72351.tiff
# Processing: 72352.tiff
# Processing: 72353.tiff
# Processing: 72354.tiff
# Processing: 72355.tiff
# Processing: 72356.tiff
# Processing: 72357.tiff
# Processing: 72358.tiff
# Processing: 72359.tiff
# Processing: 72360.tiff
# Processing: 72361.tiff
# Processing: 72362.tiff
# Processing: 72363.tiff
# Processing: 72364.tiff
# Processing: 72365.tiff
# Processing: 72366.tiff
# Processing: 72367.tiff
# Processing: 72368.tiff
# Processing: 72369.tiff
# Processing: 72370.tiff
# Processing: 72371.tiff
# Processing: 72372.tiff
# Processing: 72373.tiff
# Processing: 72374.tiff
# Processing: 72375.tiff
# Processing: 72376.tiff
# Processing: 72377.tiff
# Processing: 72378.tiff
# Processing: 72379.tiff
# Processing: 72380.tiff
# Processing: 72381.tiff
# Processing: 72382.tiff
# Processing: 72383.tiff
# Processing: 72384.tiff
# Processing: 72385.tiff
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[267], line 51
#      48 df = df[cols]
#      50 output_file = "Corneal_Endothelium_Analysis.xlsx"
# ---> 51 df.to_excel(output_file, index=False)
#      53 print(f"\nProcessing Complete! Results saved to {output_file}")
#
# File ~\cornea_env\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\cornea_env\lib\site-packages\pandas\core\generic.py:2439, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2426 from pandas.io.formats.excel import ExcelFormatter
#    2428 formatter = ExcelFormatter(
#    2429     df,
#    2430     na_rep=na_rep,
#    (...)
#    2437     inf_rep=inf_rep,
#    2438 )
# -> 2439 formatter.write(
#    2440     excel_writer,
#    2441     sheet_name=sheet_name,
#    2442     startrow=startrow,
#    2443     startcol=startcol,
#    2444     freeze_panes=freeze_panes,
#    2445     engine=engine,
#    2446     storage_options=storage_options,
#    2447     engine_kwargs=engine_kwargs,
#    2448 )
#
# File ~\cornea_env\lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File ~\cornea_env\lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)
#      66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
output_file = "Corneal_Endothelium_Analysis.xlsx"
df.to_csv(output_file, index=False)

print(f"\nProcessing Complete! Results saved to {output_file}")
# Out:
# Processing Complete! Results saved to Corneal_Endothelium_Analysis.xlsx
